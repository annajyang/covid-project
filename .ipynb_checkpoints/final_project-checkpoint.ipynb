# %% [markdown]
# ## QUESTION:
# Is there a correlation between the case rate and vaccination rate across the 50 states in March 2021?

# %%
import pandas as pd
import numpy as np

cases_url = 'United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv' 
cases_df = pd.read_csv(cases_url)

# %%
cases_df
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0          02/02/2021    IL    1130917   1130917.0         0.0      2304
# 1          06/15/2020    WI      25480     22932.0      2548.0       185
# 2          05/03/2020    NH       2518         NaN         NaN        89
# 3          03/05/2021    CA    3526939         NaN         NaN      3165
# 4          08/11/2020    GU        449         NaN         NaN        15
# ...               ...   ...        ...         ...         ...       ...
# 32095      07/23/2020    OR      15713     14900.0       813.0       319
# 32096      12/11/2020    AZ     394804    380243.0     14561.0      6986
# 32097      09/19/2020    SC     141788    137033.0      4755.0       573
# 32098      02/10/2021   FSM          1         1.0         0.0         0
# 32099      04/11/2020    NJ      58151         NaN         NaN      3563
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
def date_checker(s):
    return s[:2] == "03" and s[-2:] == '21'

date_filter = cases_df["submission_date"].apply(date_checker)
march = cases_df[date_filter]

# %%
by_state_by_date = march[march['state'] == 'CA'].sort_values('submission_date') # cannot use index column in a mask
by_state_by_date
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 28813      03/01/2021    CA    3514677         NaN         NaN      2517
# 23165      03/02/2021    CA    3516826         NaN         NaN      2149
# 2799       03/03/2021    CA    3520541         NaN         NaN      3715
# 6342       03/04/2021    CA    3523774         NaN         NaN      3233
# 3          03/05/2021    CA    3526939         NaN         NaN      3165
# 2983       03/06/2021    CA    3529853         NaN         NaN      2914
# 25348      03/07/2021    CA    3532757         NaN         NaN      2904
# 24750      03/08/2021    CA    3534937         NaN         NaN      2180
# 2795       03/09/2021    CA    3536844         NaN         NaN      1907
# 25347      03/10/2021    CA    3540166         NaN         NaN      3322
# 2871       03/11/2021    CA    3542946         NaN         NaN      2780
# 5967       03/12/2021    CA    3545697         NaN         NaN      2751
# ...

# %%
# extract only cases
month_cases = by_state_by_date['tot_cases']
month_cases
# Out:
# 28813    3514677
# 23165    3516826
# 2799     3520541
# 6342     3523774
# 3        3526939
# 2983     3529853
# 25348    3532757
# 24750    3534937
# 2795     3536844
# 25347    3540166
# 2871     3542946
# 5967     3545697
# 22745    3548280
# 24241    3550751
# 6255     3552631
# 24794    3554221
# 4003     3557089
# 2836     3559565
# 6101     3562105
# 3509     3564293
# 26896    3566450
# 4289     3568149
# 2212     3569745
# 1736     3572425
# 23225    3574903
# 29420    3577551
# 23785    3579816
# 24921    3582060
# 918      3583715
# 25724    3585308
# 2445     3587971
# Name: tot_cases, dtype: int64

# %%
import scipy.stats
scipy.stats.linregress([i for i in range(0, len(month_cases))], month_cases).slope
# Out:
# 2407.4060483870967

# %%
state_to_abbrev = {
  "Alabama": "AL",
  "Alaska": "AK",
  "Arizona": "AZ",
  "Arkansas": "AR",
  "California": "CA",
  "Colorado": "CO",
  "Connecticut": "CT",
  "Delaware": "DE",
  "Florida": "FL",
  "Georgia": "GA",
  "Hawaii": "HI",
  "Idaho": "ID",
  "Illinois": "IL",
  "Indiana": "IN",
  "Iowa": "IA",
  "Kansas": "KS",
  "Kentucky": "KY",
  "Louisiana": "LA",
  "Maine": "ME",
  "Maryland": "MD",
  "Massachusetts": "MA",
  "Michigan": "MI",
  "Minnesota": "MN",
  "Mississippi": "MS",
  "Missouri": "MO",
  "Montana": "MT",
  "Nebraska": "NE",
  "Nevada": "NV",
  "New Hampshire": "NH",
  "New Jersey": "NJ",
  "New Mexico": "NM",
  "New York": "NY",
  "North Carolina": "NC",
  "North Dakota": "ND",
  "Ohio": "OH",
  "Oklahoma": "OK",
  "Oregon": "OR",
  "Pennsylvania": "PA",
  "Puerto Rico": "PR",
  "Rhode Island": "RI",
  "South Carolina": "SC",
  "South Dakota": "SD",
  "Tennessee": "TN",
  "Texas": "TX",
  "Utah": "UT",
  "Vermont": "VT",
  "Virginia": "VA",
  "Washington": "WA",
  "West Virginia": "WV",
  "Wisconsin": "WI",
  "Wyoming": "WY"
}
abbrev_to_state = {}
for x,y in state_to_abbrev.items():
    abbrev_to_state[y] = x

# %%
# abbrevs = set(march['state'])
abbrevs = [ 'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY' ]
rates = {}
for state in abbrevs:
    by_state_by_date = march[march['state'] == state].sort_values('submission_date') # cannot use index column in a mask
    month_cases = by_state_by_date['tot_cases']
    if (len(month_cases) == 0): continue 
    rate = scipy.stats.linregress([i for i in range(0, len(month_cases))], month_cases).slope
    rates[abbrev_to_state[state]] = rate
#     print("slope for " + state +" : " +  str(rate))
    
print(rates)
# Out:
# {'Alabama': 413.74717741935484, 'Alaska': 136.29717741935485, 'Arizona': 740.8665322580645, 'Arkansas': 257.716935483871, 'California': 2407.4060483870967, 'Colorado': 1047.254435483871, 'Connecticut': 932.8645161290318, 'Delaware': 224.76774193548394, 'Florida': 4618.304032258065, 'Georgia': 1604.5620967741938, 'Hawaii': 77.04233870967744, 'Idaho': 301.1169354838711, 'Illinois': 1832.8028225806443, 'Indiana': 815.5669354838709, 'Iowa': 467.0770161290323, 'Kansas': 265.65, 'Kentucky': 601.9383064516126, 'Louisiana': 470.5310483870968, 'Maine': 193.00766129032257, 'Maryland': 962.3419354838712, 'Massachusetts': 1766.5375, 'Michigan': 3497.5205645161304, 'Minnesota': 1144.1241935483872, 'Mississippi': 305.52258064516127, 'Missouri': 536.7048387096773, 'Montana': 154.5241935483871, 'Nebraska': 259.9209677419356, 'Nevada': 330.6935483870969, 'New Hampshire': 283.6487903225807, 'New Jersey': 3891.9225806451614, 'New Mexico': 204.7516129032258, 'New York': 3443.2173387096786, 'North Caroli
# ...

# %%
final_cases = pd.DataFrame.from_dict(rates.items())
final_cases
# Out:
#                  0            1
# 0          Alabama   413.747177
# 1           Alaska   136.297177
# 2          Arizona   740.866532
# 3         Arkansas   257.716935
# 4       California  2407.406048
# 5         Colorado  1047.254435
# 6      Connecticut   932.864516
# 7         Delaware   224.767742
# 8          Florida  4618.304032
# 9          Georgia  1604.562097
# 10          Hawaii    77.042339
# 11           Idaho   301.116935
# 12        Illinois  1832.802823
# 13         Indiana   815.566935
# 14            Iowa   467.077016
# 15          Kansas   265.650000
# 16        Kentucky   601.938306
# 17       Louisiana   470.531048
# 18           Maine   193.007661
# 19        Maryland   962.341935
# 20   Massachusetts  1766.537500
# 21        Michigan  3497.520565
# 22       Minnesota  1144.124194
# 23     Mississippi   305.522581
# 24        Missouri   536.704839
# 25         Montana   154.524194
# 26        Nebraska   259.920968
# 27          Nevada   330.693548
# ...

# %%
import pandas as pd
import numpy as np
import scipy

raw_data = pd.read_csv("us-daily-covid-vaccine-doses-administered.csv")

s = set()
for i, r in raw_data.iterrows():
    s.add(r["Entity"])
    
df = pd.DataFrame(columns=["State", "Vacc_Rate", "Case_Rate"])

def in_march(s):
    if s[6] == "3":
        return True
    return False

for state in s:
    data = raw_data.loc[(raw_data["Entity"] == state) & (raw_data["Day"].apply(in_march))]["daily_vaccinations"]
    #print (data.shape)
    arr = np.array(data)
    df.loc[df.shape[0]] = [state, scipy.stats.linregress(np.arange(1, arr.size+1), y=arr).slope, ""]
    #if state == "Alabama":
        #print (arr)

# %%
final_vacc = df
final_vacc
# Out:
#             State     Vacc_Rate Case_Rate
# 0         Arizona    190.450806
# 1    Pennsylvania   1939.028629
# 2    Rhode Island     91.996371
# 3            Utah    149.722984
# 4    South Dakota     74.395161
# ..            ...           ...       ...
# 60        Vermont     61.937903
# 61       Virginia    524.818548
# 62          Idaho     95.371371
# 63         Alaska      9.961290
# 64  United States  26962.627419
#
# [65 rows x 3 columns]

# %%
final_df = final_cases.merge(final_vacc, left_on = 0, right_on = 'State').drop(labels = ['Case_Rate', 0], axis = 1).rename(mapper = {1: 'Case_Rate'}, axis = 1)
final_df = final_df.set_index("State")
# axis = 1 => apply to columns

# %%
import matplotlib.pyplot as plt

plt.scatter(final_df['Case_Rate'], final_df['Vacc_Rate'])
plt.xlabel("Daily Case Rate")
plt.ylabel("Daily Vaccination Rate")


m, b = np.polyfit(final_df['Case_Rate'], final_df['Vacc_Rate'], 1)
ind = np.arange(max(final_df['Case_Rate']))
plt.plot(ind, m*ind+ b, color = 'red')

# %%
final_df['slopes'] = final_df['Case_Rate'] / final_df['Vacc_Rate']
final_df.sort_values('slopes')
# Out:
#                   Case_Rate    Vacc_Rate     slopes
# State
# Wyoming           60.327823    -0.738306 -81.711087
# Mississippi      305.522581  -189.621371  -1.611224
# California      2407.406048  6460.695161   0.372623
# Kansas           265.650000   380.964113   0.697310
# Georgia         1604.562097  1702.020161   0.942740
# Wisconsin        591.217742   617.202419   0.957899
# Maine            193.007661   179.454032   1.075527
# New Mexico       204.751613   167.180645   1.224733
# Colorado        1047.254435   810.079032   1.292781
# Oregon           303.559274   227.952419   1.331678
# Ohio            1569.407258  1163.500403   1.348867
# Pennsylvania    2952.497984  1939.028629   1.522669
# Hawaii            77.042339    43.148387   1.785521
# North Carolina  1650.349597   856.285484   1.927336
# Vermont          122.848790    61.937903   1.983419
# Nevada           330.693548   154.247984   2.143908
# Illinois        1832.802823   850.818952   2.154163
# ...

# %% [markdown]
# ## Conclusion
# YES, there is a positive correlation between case rate and vaccination rate.
